# %% [markdown]
# ## Code for Finding Prime Numbers within any range

# %%
i=2
while (i<100):
    j=2
    while (j<i):
        if i%j == 0:
            break;
        j=j+1
    if (j==i):
        print (i, "is prime")
    i=i+1
# Out:
# 2 is prime
# 3 is prime
# 5 is prime
# 7 is prime
# 11 is prime
# 13 is prime
# 17 is prime
# 19 is prime
# 23 is prime
# 29 is prime
# 31 is prime
# 37 is prime
# 41 is prime
# 43 is prime
# 47 is prime
# 53 is prime
# 59 is prime
# 61 is prime
# 67 is prime
# 71 is prime
# 73 is prime
# 79 is prime
# 83 is prime
# 89 is prime
# 97 is prime

# %%
def primes (x,y):
    """Function for finding prime nos."""
    for i in range(x,y):
        j=2;
        while (j<i):
            isPrime = 1;
            if i%j==0:
                isPrime = 0;
            break;
        j=j+1;
        if (isPrime):
            print (i, "is a Prime");
        i=i+1;
a = primes (x=15, y=25)   
b = primes(x=100, y=250)
c= primes (x=10000, y=10200)
# Out:
# 15 is a Prime
# 17 is a Prime
# 19 is a Prime
# 21 is a Prime
# 23 is a Prime
# 101 is a Prime
# 103 is a Prime
# 105 is a Prime
# 107 is a Prime
# 109 is a Prime
# 111 is a Prime
# 113 is a Prime
# 115 is a Prime
# 117 is a Prime
# 119 is a Prime
# 121 is a Prime
# 123 is a Prime
# 125 is a Prime
# 127 is a Prime
# 129 is a Prime
# 131 is a Prime
# 133 is a Prime
# 135 is a Prime
# 137 is a Prime
# 139 is a Prime
# 141 is a Prime
# 143 is a Prime
# 145 is a Prime
# 147 is a Prime
# 149 is a Prime
# 151 is a Prime
# 153 is a Prime
# 155 is a Prime
# 157 is a Prime
# 159 is a Prime
# 161 is a Prime
# 163 is a Prime
# 165 is a Prime
# 167 is a Prime
# 169 is a Prime
# 171 is a Prime
# 173 is a Prime
# 175 is a Prime
# 177 is a Prime
# 179 is a Prime
# 181 is a Prime
# 183 is a Prime
# 185 is a Prime
# 187 is a Prime
# 189 is a Prime
# 191 is a Prime
# 193 is a Prime
# 195 is a Prime
# 197 is a Prime
# 199 is a Prime
# 201 is a Prime
# 203 is a Prime
# 205 is a Prime
# 207 is a Prime
# ...
